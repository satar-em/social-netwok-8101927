# %%
import sys, pathlib
from importlib import reload

ROOT = pathlib.Path().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

# %% [markdown]
# # Q01

# %%
import questions.q01 as q01
reload(q01)

print(q01.run())

# %% [markdown]
# # Q02

# %%
import questions.q02 as q02
reload(q02)

print(q02.run())

# %% [markdown]
# # Q03

# %%
import questions.q03 as q03
reload(q03)

print(q03.run())

# %% [markdown]
# # Q04

# %%
import questions.q04 as q04

reload(q04)

print(q04.run())

# %% [markdown]
# # Q05

# %%
import questions.q05 as q05

reload(q05)

print(q05.run())

# %% [markdown]
# # Q06

# %%
import questions.q06 as q06

reload(q06)

print(q06.run())

# %% [markdown]
# # Q07

# %%
import questions.q07 as q07

reload(q07)

print(q07.run())

# %% [markdown]
# # Q08

# %%
import questions.q08 as q08

reload(q08)

print(q08.run())

# %% [markdown]
# # Q09

# %%
import questions.q09 as q09

reload(q09)

print(q09.run())

# %% [markdown]
# # Q10

# %%
import questions.q10 as q10

reload(q10)

print(q10.run())

# %% [markdown]
# # Q11

# %%
import questions.q11 as q11

reload(q11)

print(q11.run())
